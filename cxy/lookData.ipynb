# %%
import pandas as pd
data = pd.read_csv('./data/content_marktag_201807.csv')
data[['ruleNameList','correctResult','content','mark_tag']]
# Out:
#            ruleNameList correctResult  \
# 0              ['售后问题']         ['2']
# 1            ['禁忌部门名称']         ['1']
# 2               ['敏感词']         ['1']
# 3                ['投诉']         ['2']
# 4            ['夸大肥胖后果']         ['1']
# 5            ['夸大肥胖后果']         ['1']
# 6               ['敏感词']         ['2']
# 7              ['禁忌称谓']         ['2']
# 8               ['敏感词']         ['2']
# 9         ['服务态度生硬/恶劣']         ['2']
# 10        ['服务态度生硬/恶劣']         ['2']
# 11             ['草率销售']         ['2']
# 12             ['禁忌称谓']         ['1']
# 13              ['敏感词']         ['2']
# 14             ['透明营销']         ['2']
# 15          ['违反1+1模式']         ['2']
# 16             ['售后问题']         ['1']
# 17              ['敏感词']         ['2']
# 18           ['违反指南销售']         ['2']
# 19             ['泄露机密']         ['2']
# 20              ['敏感词']         ['2']
# 21        ['服务态度生硬/恶劣']         ['1']
# 22          ['违反1+1模式']         ['1']
# ...

# %%
for line in data['content']:
    print(line)
    print()
# Out:
# xuguiying\t2018-07-10 18:11:40\r\n顾问让记预约编号，以后每隔三个月会给客户做一次回访，手上产品能处理就会帮客户去处理不会让客户白花。\r\n
# xuguiying\t2018-07-11 16:17:40\r\n顾问让记预约编号，表示以后每隔大概三个月会给客户做一次回访，因为是做公司的口碑，平时减体重的人是两三百斤的人，客户担心自己一百多斤的能不能减，顾问称要了解之后才会去做，客户问如果搞不定怎么办，顾问称如果搞不定，手上产品能处理就会帮客户去处理，吃了不吸收也没有用，不会让客户白花，而且这次是安排总部营养师郑先生，是总部资深顾问最高级别的，还帮客户打听了费用方面，如果要求高的费用方面大概3-4千甚至上万都有，如果单方面把代谢方面和补充分解酶费用方面大概2千来块左右，到时就是根据自己经济情况；交代客户到时问手上产品后期能否去用，如果能用会结合去用，如果用不上那边会帮客户去处理，把损失降到最低；预约时间是3点40-45或者4点左右，会跟客户亲自沟通了解，大概20-30分钟；称在那边打听到，会根据客户的身高年龄减到标准体重是100-105斤，让客户沟通完来电，客户称好。\r\n
#
# mengshan\t2018-07-11 10:14:06\r\n了解客户反应，第一次减肥，称不敢指导了，已经加量了的，代谢不好；客户说涨的难受，就用了开塞露，排的时候挺正常，不用的时候就堵上，没用产品的时候三四天四五天排一次；顾问建议递交资料到总部资深顾问那里去分析体质问题，问客户有没有三高这些？[20:04]客户说没有，顾问让注意一下，帮预约资深顾问分析体质，告知预约编号，帮预约的是孔先生。\r\n
#
# sunti\t2018-07-11 10:11:39\r\n了解客户瘦身反应，75公斤，感觉秤坏了，酒吧销售酒，从170减到150拔罐减10斤，自己慢慢瘦了10斤，左旋肉碱没减，现在吃少1顿，晚睡，上个月刚打掉孩子。顾问分析客户肥胖原因：吸收不好，代谢慢，调整用法，9号联系。\r\n
#
# liufuqiuyan1\t2018-07-11 18:16:04\r\n[38:01]顾问让客户一遍通话一遍操作。【转写错误】\r\n
#
# weikunyi\t2018-07-11 18:07:50\r\n顾问举例的是其他客户没配合好，\r\n
# ...
